# %% [markdown]
# <a href="https://colab.research.google.com/github/unmiulast/Tokyo/blob/main/6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
#階層型インデックス
hier_df = DataFrame(
    np.arange(9).reshape((3,3)),
    index = [
        ['a','a','b'],
        [1,2,2]
    ],
    columns = [
        ['Osaka','Tokyo','Osaka'],
        ['Blue','Red','Red']
    ]
)

hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
hier_df.index.names =['key1','key2']

hier_df.columns.names = ['city','color']

hier_df
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5
# b    2        6     7     8

# %%
 #カラムの絞り込み
 hier_df['Osaka']
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    2
#      2        3    5
# b    2        6    8

# %%
hier_df.xs('Red', level='color', axis=1)
# Out:
# city       Tokyo  Osaka
# key1 key2
# a    1         1      2
#      2         4      5
# b    2         7      8

# %%
#インデックスを軸に集計
#行方向(axis=0)に集計
#groupby は常に「行方向」で動く仕様になっている
hier_df.groupby(level="key2").sum()
# Out:
# city  Osaka Tokyo Osaka
# color  Blue   Red   Red
# key2
# 1         0     1     2
# 2         9    11    13

# %%
#列方向をまとめたい場合は T（転置）してから groupby を使います。
hier_df.T.groupby(level = 'color').sum().T
# Out:
# color      Blue  Red
# key1 key2
# a    1        0    3
#      2        3    9
# b    2        6   15

# %%
hier_df.drop(['b'])
# Out:
# city      Osaka Tokyo Osaka
# color      Blue   Red   Red
# key1 key2
# a    1        0     1     2
#      2        3     4     5

# %%
hier_df = DataFrame(
    np.arange(12).reshape((3,4)),
    index = [
        ['c','d','d'],
        [1, 2, 1]
        ],
    columns = [
        ['Kyoto','Nagoya','Hokkaido','Kyoto'],
        ['Yellow','Yellow','Red','Blue']
        ]
)
hier_df.index.names = ['key1','key2']
hier_df.columns.names = ['city','color']
hier_df
# Out:
# city       Kyoto Nagoya Hokkaido Kyoto
# color     Yellow Yellow      Red  Blue
# key1 key2
# c    1         0      1        2     3
# d    2         4      5        6     7
#      1         8      9       10    11

# %%
hier_df['Kyoto']
# Out:
# color      Yellow  Blue
# key1 key2
# c    1          0     3
# d    2          4     7
#      1          8    11

# %%
hier_df.T.groupby(level = 'city').mean().T
# Out:
# city       Hokkaido  Kyoto  Nagoya
# key1 key2
# c    1          2.0    1.5     1.0
# d    2          6.0    5.5     5.0
#      1         10.0    9.5     9.0

# %%
hier_df.groupby(level = 'key2').sum()
# Out:
# city   Kyoto Nagoya Hokkaido Kyoto
# color Yellow Yellow      Red  Blue
# key2
# 1          8     10       12    14
# 2          4      5        6     7

# %%
data1 = {
    'id':['100','101','102','103','104','106','108','110','111','113'],
    'city':['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo','Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
    'birth_year':[1990,1989,1992,1997,1982,1991,1988,1990,1995,1981],
    'name':['Hiroshi','Akiko','Yuki','Satoru','Steeve','Mituru','Aoi','Tarou','Suguru','Mitsuo']
}

df1 = DataFrame(data1)
df1
# Out:
#     id      city  birth_year     name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982   Steeve
# 5  106     Tokyo        1991   Mituru
# 6  108     Osaka        1988      Aoi
# 7  110     Kyoto        1990    Tarou
# 8  111  Hokkaido        1995   Suguru
# 9  113     Tokyo        1981   Mitsuo

# %%
data2 = {
    'id':['100', '101', '102', '105', '107'],
    'math':[50,43,33,76,98],
    'English':[90,30,20,50,30],
    'sex':['M','F','F','M','M'],
    'index_num':[0,1,2,3,4]
}

df2 = DataFrame(data2)
df2
# Out:
#     id  math  English sex  index_num
# 0  100    50       90   M          0
# 1  101    43       30   F          1
# 2  102    33       20   F          2
# 3  105    76       50   M          3
# 4  107    98       30   M          4

# %%
#内部結合(mergeのデフォルト,キーは自動認識,onで明示可能)
pd.merge(df1,df2, on = 'id')
# Out:
#     id   city  birth_year     name  math  English sex  index_num
# 0  100  Tokyo        1990  Hiroshi    50       90   M          0
# 1  101  Osaka        1989    Akiko    43       30   F          1
# 2  102  Kyoto        1992     Yuki    33       20   F          2

# %%
#全結合(howパラメータにouterを指定)
pd.merge(df1,df2,how = 'outer')
# Out:
#      id      city  birth_year     name  math  English  sex  index_num
# 0   100     Tokyo      1990.0  Hiroshi  50.0     90.0    M        0.0
# 1   101     Osaka      1989.0    Akiko  43.0     30.0    F        1.0
# 2   102     Kyoto      1992.0     Yuki  33.0     20.0    F        2.0
# 3   103  Hokkaido      1997.0   Satoru   NaN      NaN  NaN        NaN
# 4   104     Tokyo      1982.0   Steeve   NaN      NaN  NaN        NaN
# 5   105       NaN         NaN      NaN  76.0     50.0    M        3.0
# 6   106     Tokyo      1991.0   Mituru   NaN      NaN  NaN        NaN
# 7   107       NaN         NaN      NaN  98.0     30.0    M        4.0
# 8   108     Osaka      1988.0      Aoi   NaN      NaN  NaN        NaN
# 9   110     Kyoto      1990.0    Tarou   NaN      NaN  NaN        NaN
# 10  111  Hokkaido      1995.0   Suguru   NaN      NaN  NaN        NaN
# 11  113     Tokyo      1981.0   Mitsuo   NaN      NaN  NaN        NaN

# %%
#インデックスによるmerge
#これは「df1 のインデックス」と「df2['index_num'] の列」を結合キーにしています。
pd.merge(df1,df2, left_index = True, right_on = 'index_num')
# Out:
#   id_x      city  birth_year     name id_y  math  English sex  index_num
# 0  100     Tokyo        1990  Hiroshi  100    50       90   M          0
# 1  101     Osaka        1989    Akiko  101    43       30   F          1
# 2  102     Kyoto        1992     Yuki  102    33       20   F          2
# 3  103  Hokkaido        1997   Satoru  105    76       50   M          3
# 4  104     Tokyo        1982   Steeve  107    98       30   M          4

# %%
#左外部結合(howパラメータにleftを指定)
pd.merge(df1,df2,how = 'left')
# Out:
#     id      city  birth_year     name  math  English  sex  index_num
# 0  100     Tokyo        1990  Hiroshi  50.0     90.0    M        0.0
# 1  101     Osaka        1989    Akiko  43.0     30.0    F        1.0
# 2  102     Kyoto        1992     Yuki  33.0     20.0    F        2.0
# 3  103  Hokkaido        1997   Satoru   NaN      NaN  NaN        NaN
# 4  104     Tokyo        1982   Steeve   NaN      NaN  NaN        NaN
# 5  106     Tokyo        1991   Mituru   NaN      NaN  NaN        NaN
# 6  108     Osaka        1988      Aoi   NaN      NaN  NaN        NaN
# 7  110     Kyoto        1990    Tarou   NaN      NaN  NaN        NaN
# 8  111  Hokkaido        1995   Suguru   NaN      NaN  NaN        NaN
# 9  113     Tokyo        1981   Mitsuo   NaN      NaN  NaN        NaN

# %%
data3 = {
    'id':['117','118','119','120','125'],
    'city':['Chiba','Kanagawa','Tokyo','Fukuoka','Okinawa'],
    'birth_year':[1990,1989,1992,1997,1982],
    'name':['Suguru','Kouichi','Satoshi','Yukie','Akari']
}
df3 = DataFrame(data3)
df3
# Out:
#     id      city  birth_year     name
# 0  117     Chiba        1990   Suguru
# 1  118  Kanagawa        1989  Kouichi
# 2  119     Tokyo        1992  Satoshi
# 3  120   Fukuoka        1997    Yukie
# 4  125   Okinawa        1982    Akari

# %%
#縦結合(データを縦に積み上げ)
concat_data = pd.concat([df1,df3])
concat_data
# Out:
#     id      city  birth_year     name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982   Steeve
# 5  106     Tokyo        1991   Mituru
# 6  108     Osaka        1988      Aoi
# 7  110     Kyoto        1990    Tarou
# 8  111  Hokkaido        1995   Suguru
# 9  113     Tokyo        1981   Mitsuo
# 0  117     Chiba        1990   Suguru
# 1  118  Kanagawa        1989  Kouichi
# 2  119     Tokyo        1992  Satoshi
# 3  120   Fukuoka        1997    Yukie
# 4  125   Okinawa        1982    Akari

# %%
 #indexの振りなおし（drop = Trueで古いindexを削除）
concat_data.reset_index(drop = True)
# Out:
#      id      city  birth_year     name
# 0   100     Tokyo        1990  Hiroshi
# 1   101     Osaka        1989    Akiko
# 2   102     Kyoto        1992     Yuki
# 3   103  Hokkaido        1997   Satoru
# 4   104     Tokyo        1982   Steeve
# 5   106     Tokyo        1991   Mituru
# 6   108     Osaka        1988      Aoi
# 7   110     Kyoto        1990    Tarou
# 8   111  Hokkaido        1995   Suguru
# 9   113     Tokyo        1981   Mitsuo
# 10  117     Chiba        1990   Suguru
# 11  118  Kanagawa        1989  Kouichi
# 12  119     Tokyo        1992  Satoshi
# 13  120   Fukuoka        1997    Yukie
# 14  125   Okinawa        1982    Akari

# %%
data4 ={
    'id':[0,1,2,3,4,6,8,11,12,13],
    'city':['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo','Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
    'birth_year':[1990,1989,1992,1997,1982,1992,1988,1990,1995,1981],
    'name':['Hiroshi','Akiko','Yuki','Satoru','Steeve','Mituru','Aoi','Tarou','Suguru','Mitsuo']
}
df4 = DataFrame(data4)
df4
# Out:
#    id      city  birth_year     name
# 0   0     Tokyo        1990  Hiroshi
# 1   1     Osaka        1989    Akiko
# 2   2     Kyoto        1992     Yuki
# 3   3  Hokkaido        1997   Satoru
# 4   4     Tokyo        1982   Steeve
# 5   6     Tokyo        1992   Mituru
# 6   8     Osaka        1988      Aoi
# 7  11     Kyoto        1990    Tarou
# 8  12  Hokkaido        1995   Suguru
# 9  13     Tokyo        1981   Mitsuo

# %%
data5 ={
    'id':[0,1,3,6,8],
    'math':[20,30,50,70,90],
    'English':[30,50,50,70,20],
    'sex':['M','F','F','M','M'],
    'index_num':[0,1,2,3,4]
}
df5 = DataFrame(data5)
df5
# Out:
#    id  math  English sex  index_num
# 0   0    20       30   M          0
# 1   1    30       50   F          1
# 2   3    50       50   F          2
# 3   6    70       70   M          3
# 4   8    90       20   M          4

# %%
df = pd.merge(df4,df5,how = 'outer')
df
# Out:
#    id      city  birth_year     name  math  English  sex  index_num
# 0   0     Tokyo        1990  Hiroshi  20.0     30.0    M        0.0
# 1   1     Osaka        1989    Akiko  30.0     50.0    F        1.0
# 2   2     Kyoto        1992     Yuki   NaN      NaN  NaN        NaN
# 3   3  Hokkaido        1997   Satoru  50.0     50.0    F        2.0
# 4   4     Tokyo        1982   Steeve   NaN      NaN  NaN        NaN
# 5   6     Tokyo        1992   Mituru  70.0     70.0    M        3.0
# 6   8     Osaka        1988      Aoi  90.0     20.0    M        4.0
# 7  11     Kyoto        1990    Tarou   NaN      NaN  NaN        NaN
# 8  12  Hokkaido        1995   Suguru   NaN      NaN  NaN        NaN
# 9  13     Tokyo        1981   Mitsuo   NaN      NaN  NaN        NaN

# %%
data6 = {
    'id':[70,80,90,120,150],
    'city':['Chiba','Kanagawa','Tokyo','Fukuoka','Okinawa'],
    'birth_year':[1980,1999,1995,1994,1994],
    'name':['Suguru','Kouichi','Satoshi','Yukie','Akari']
}

df6 = DataFrame(data6)
df6
# Out:
#     id      city  birth_year     name
# 0   70     Chiba        1980   Suguru
# 1   80  Kanagawa        1999  Kouichi
# 2   90     Tokyo        1995  Satoshi
# 3  120   Fukuoka        1994    Yukie
# 4  150   Okinawa        1994    Akari

# %%
concat_df = pd.concat([df4,df6])
concat_df
# Out:
#     id      city  birth_year     name
# 0    0     Tokyo        1990  Hiroshi
# 1    1     Osaka        1989    Akiko
# 2    2     Kyoto        1992     Yuki
# 3    3  Hokkaido        1997   Satoru
# 4    4     Tokyo        1982   Steeve
# 5    6     Tokyo        1992   Mituru
# 6    8     Osaka        1988      Aoi
# 7   11     Kyoto        1990    Tarou
# 8   12  Hokkaido        1995   Suguru
# 9   13     Tokyo        1981   Mitsuo
# 0   70     Chiba        1980   Suguru
# 1   80  Kanagawa        1999  Kouichi
# 2   90     Tokyo        1995  Satoshi
# 3  120   Fukuoka        1994    Yukie
# 4  150   Okinawa        1994    Akari

# %%
#ピボット操作(行を列に，列を行に)
#階層型インデックス
hier_df = DataFrame(
    np.arange(9).reshape((3,3)),
    index = [
        ['a','a','b'],
        [1,2,2]
    ],
    columns = [
        ['Osaka','Tokyo','Osaka'],
        ['Blue','Red','Red']
    ]
)

hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
#「Blue,Red」の列を行に
#stack() は 列の最内層を行方向に積み上げて Series にします(level =で指定可能)
hier_df.stack(future_stack=True)
hier_df
# Out:
#     Osaka Tokyo Osaka
#      Blue   Red   Red
# a 1     0     1     2
#   2     3     4     5
# b 2     6     7     8

# %%
hier_df = hier_df.unstack()
hier_df
# Out:
#   Osaka      Tokyo      Osaka
#    Blue        Red        Red
#       1    2     1    2     1    2
# a   0.0  3.0   1.0  4.0   2.0  5.0
# b   NaN  6.0   NaN  7.0   NaN  8.0

# %%
dupli_data = DataFrame({
    'col1':[1,1,2,3,4,4,6,6],
    'col2':['a','b','b','b','c','c','b','b']
})
dupli_data
# Out:
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 5     4    c
# 6     6    b
# 7     6    b

# %%
#重複判定(両方のカラムが重複しているとき2回目でTrueになる)
dupli_data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
#重複削除
dupli_data.drop_duplicates()
# Out:
#    col1 col2
# 0     1    a
# 1     1    b
# 2     2    b
# 3     3    b
# 4     4    c
# 6     6    b

# %%
#マッピング処理(vlookup関数)
#共通のキーに対応するデータを参照のテーブルから引っ張ってくる機能

#参照データ
city_map ={
    'Tokyo':'Kanto',
    'Hokkaido':'Hokkaido',
    'Osaka':'Kansai',
    'Kyoto':'Kansai'
}
city_map
# Out:
# {'Tokyo': 'Kanto',
#  'Hokkaido': 'Hokkaido',
#  'Osaka': 'Kansai',
#  'Kyoto': 'Kansai'}

# %%
df1
# Out:
#     id      city  birth_year     name
# 0  100     Tokyo        1990  Hiroshi
# 1  101     Osaka        1989    Akiko
# 2  102     Kyoto        1992     Yuki
# 3  103  Hokkaido        1997   Satoru
# 4  104     Tokyo        1982   Steeve
# 5  106     Tokyo        1991   Mituru
# 6  108     Osaka        1988      Aoi
# 7  110     Kyoto        1990    Tarou
# 8  111  Hokkaido        1995   Suguru
# 9  113     Tokyo        1981   Mitsuo

# %%
#参照データを結合
df1['region']=df1['city'].map(city_map)
df1
# Out:
#     id      city  birth_year     name    region
# 0  100     Tokyo        1990  Hiroshi     Kanto
# 1  101     Osaka        1989    Akiko    Kansai
# 2  102     Kyoto        1992     Yuki    Kansai
# 3  103  Hokkaido        1997   Satoru  Hokkaido
# 4  104     Tokyo        1982   Steeve     Kanto
# 5  106     Tokyo        1991   Mituru     Kanto
# 6  108     Osaka        1988      Aoi    Kansai
# 7  110     Kyoto        1990    Tarou    Kansai
# 8  111  Hokkaido        1995   Suguru  Hokkaido
# 9  113     Tokyo        1981   Mitsuo     Kanto

# %%
df1['up_two_num'] = df1['birth_year'].map(lambda x : str(x)[0:3])
df1
# Out:
#     id      city  birth_year     name    region up_two_num
# 0  100     Tokyo        1990  Hiroshi     Kanto        199
# 1  101     Osaka        1989    Akiko    Kansai        198
# 2  102     Kyoto        1992     Yuki    Kansai        199
# 3  103  Hokkaido        1997   Satoru  Hokkaido        199
# 4  104     Tokyo        1982   Steeve     Kanto        198
# 5  106     Tokyo        1991   Mituru     Kanto        199
# 6  108     Osaka        1988      Aoi    Kansai        198
# 7  110     Kyoto        1990    Tarou    Kansai        199
# 8  111  Hokkaido        1995   Suguru  Hokkaido        199
# 9  113     Tokyo        1981   Mitsuo     Kanto        198

# %%
#ビン分割(離散的範囲にデータを分割)
#分割の粒度
birth_year_bins = [1980,1985,1990,1995,2000]

#「1980~1985」に1980は含まないが1985は含む（〜より後で，〜以前）

#ビン分割の実施(pd.cut関数（分割するデータ.カラム,分割する境界値）)
birth_year_cut_data = pd.cut(df1.birth_year,birth_year_bins)
birth_year_cut_data
# Out:
# 0    (1985, 1990]
# 1    (1985, 1990]
# 2    (1990, 1995]
# 3    (1995, 2000]
# 4    (1980, 1985]
# 5    (1990, 1995]
# 6    (1985, 1990]
# 7    (1985, 1990]
# 8    (1990, 1995]
# 9    (1980, 1985]
# Name: birth_year, dtype: category
# Categories (4, interval[int64, right]): [(1980, 1985] < (1985, 1990] < (1990, 1995] < (1995, 2000]]

# %%
pd.value_counts(birth_year_cut_data)
# Out:
# /tmp/ipython-input-1731862176.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(birth_year_cut_data)
# birth_year
# (1985, 1990]    4
# (1990, 1995]    3
# (1980, 1985]    2
# (1995, 2000]    1
# Name: count, dtype: int64

# %%
group_names = ['early1980s','late1980s','early1990s','late1990s']
birth_year_cut_data = pd.cut(df1.birth_year,birth_year_bins, labels = group_names)
pd.value_counts(birth_year_cut_data)
# Out:
# /tmp/ipython-input-880964082.py:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(birth_year_cut_data)
# birth_year
# late1980s     4
# early1990s    3
# early1980s    2
# late1990s     1
# Name: count, dtype: int64

# %%
#数字で分割数を指定可能
pd.cut(df1.birth_year,2)
# Out:
# 0      (1989.0, 1997.0]
# 1    (1980.984, 1989.0]
# 2      (1989.0, 1997.0]
# 3      (1989.0, 1997.0]
# 4    (1980.984, 1989.0]
# 5      (1989.0, 1997.0]
# 6    (1980.984, 1989.0]
# 7      (1989.0, 1997.0]
# 8      (1989.0, 1997.0]
# 9    (1980.984, 1989.0]
# Name: birth_year, dtype: category
# Categories (2, interval[float64, right]): [(1980.984, 1989.0] < (1989.0, 1997.0]]

# %%
#qcut関数は分位点での分割が可能(同じサイズのビンが作成できる)
pd.value_counts(pd.qcut(df1.birth_year,2))
# Out:
# /tmp/ipython-input-1868677308.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(pd.qcut(df1.birth_year,2))
# birth_year
# (1980.999, 1990.0]    6
# (1990.0, 1997.0]      4
# Name: count, dtype: int64

# %%
df = pd.read_csv('/content/student-mat.csv',sep = ';')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df['age_twice'] = df['age'].map(lambda x: x*2)
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
absences_bins = [0,1,5,100]

absences_data = pd.cut(df.absences,absences_bins,right = False)
pd.value_counts(absences_data)
# Out:
# /tmp/ipython-input-3257465429.py:4: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(absences_data)
# absences
# [5, 100)    151
# [1, 5)      129
# [0, 1)      115
# Name: count, dtype: int64

# %%
pd.value_counts(pd.qcut(df.absences,3))
# Out:
# /tmp/ipython-input-2444386271.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(pd.qcut(df.absences,3))
# absences
# (-0.001, 2.0]    183
# (6.0, 75.0]      115
# (2.0, 6.0]        97
# Name: count, dtype: int64

# %%
df1
# Out:
#     id      city  birth_year     name    region up_two_num
# 0  100     Tokyo        1990  Hiroshi     Kanto        199
# 1  101     Osaka        1989    Akiko    Kansai        198
# 2  102     Kyoto        1992     Yuki    Kansai        199
# 3  103  Hokkaido        1997   Satoru  Hokkaido        199
# 4  104     Tokyo        1982   Steeve     Kanto        198
# 5  106     Tokyo        1991   Mituru     Kanto        199
# 6  108     Osaka        1988      Aoi    Kansai        198
# 7  110     Kyoto        1990    Tarou    Kansai        199
# 8  111  Hokkaido        1995   Suguru  Hokkaido        199
# 9  113     Tokyo        1981   Mitsuo     Kanto        198

# %%
#size
df1.groupby('city').size()
# Out:
# city
# Hokkaido    2
# Kyoto       2
# Osaka       2
# Tokyo       4
# dtype: int64

# %%
#city軸でbirth_yearの平均値を求める
df1.groupby('city')['birth_year'].mean()
# Out:
# city
# Hokkaido    1996.0
# Kyoto       1991.0
# Osaka       1988.5
# Tokyo       1986.0
# Name: birth_year, dtype: float64

# %%
#複数軸
df1.groupby(['region','city'])['birth_year'].mean()
# Out:
# region    city
# Hokkaido  Hokkaido    1996.0
# Kansai    Kyoto       1991.0
#           Osaka       1988.5
# Kanto     Tokyo       1986.0
# Name: birth_year, dtype: float64

# %%
#as_index = Falseを設定するとインデックスが設定されなくなる
df1.groupby(['region','city'],as_index = False)['birth_year'].mean()
# Out:
#      region      city  birth_year
# 0  Hokkaido  Hokkaido      1996.0
# 1    Kansai     Kyoto      1991.0
# 2    Kansai     Osaka      1988.5
# 3     Kanto     Tokyo      1986.0

# %%
#groupbyにはイテレータという反復的に値を取り出す機能があり，結果の要素をforループ処理できて便利
#groupはregionを取り出し, subdfはそのregionの行を全て抽出する
for group, subdf in df1.groupby('region'):
  print('='*60)
  print('Region Name:{0}'.format(group))
  print(subdf)
# Out:
# ...
# Region Name:Hokkaido
#     id      city  birth_year    name    region up_two_num
# 3  103  Hokkaido        1997  Satoru  Hokkaido        199
# 8  111  Hokkaido        1995  Suguru  Hokkaido        199
# ...
# Region Name:Kansai
#     id   city  birth_year   name  region up_two_num
# 1  101  Osaka        1989  Akiko  Kansai        198
# 2  102  Kyoto        1992   Yuki  Kansai        199
# 6  108  Osaka        1988    Aoi  Kansai        198
# 7  110  Kyoto        1990  Tarou  Kansai        199
# ...
# Region Name:Kanto
#     id   city  birth_year     name region up_two_num
# 0  100  Tokyo        1990  Hiroshi  Kanto        199
# 4  104  Tokyo        1982   Steeve  Kanto        198
# 5  106  Tokyo        1991   Mituru  Kanto        199
# 9  113  Tokyo        1981   Mitsuo  Kanto        198

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
functions = ['count','mean','max','min']
df_group = df.groupby(['sex','address'])
df_group[['age','G1']].agg(functions)
# Out:
#               age                       G1
#             count       mean max min count       mean max min
# sex address
# F   R          44  16.977273  19  15    44  10.295455  19   6
#     U         164  16.664634  20  15   164  10.707317  18   4
# M   R          44  17.113636  21  15    44  10.659091  18   3
#     U         143  16.517483  22  15   143  11.405594  19   5

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.groupby('school')['G1'].mean()
# Out:
# school
# GP    10.939828
# MS    10.673913
# Name: G1, dtype: float64

# %%
df.groupby(['school','sex'])[['G1','G2','G3']].mean()
# Out:
#                    G1         G2         G3
# school sex
# GP     F    10.579235  10.398907   9.972678
#        M    11.337349  11.204819  11.060241
# MS     F    10.920000  10.320000   9.920000
#        M    10.380952  10.047619   9.761905

# %%
function2 = ['max','min']
df_group2 = df.groupby(['school','sex'])
df_group2[['G1','G2','G3']].agg(function2)
# Out:
#             G1      G2      G3
#            max min max min max min
# school sex
# GP     F    18   4  18   0  19   0
#        M    19   3  19   0  20   0
# MS     F    19   6  18   5  19   0
#        M    15   6  16   5  16   0

# %%
from numpy import nan as NA
df  = pd.DataFrame(np.random.rand(10,4))

df.iloc[1,0] = NA
df.iloc[2:3,2] = NA
df.iloc[5:,3]  = NA

df
# Out:
#           0         1         2         3
# 0  0.602468  0.768027  0.766677  0.449735
# 1       NaN  0.923134  0.971350  0.540832
# 2  0.666241  0.240078       NaN  0.326597
# 3  0.811484  0.744376  0.333719  0.533052
# 4  0.817702  0.421772  0.268190  0.029585
# 5  0.663275  0.565867  0.247369       NaN
# 6  0.678600  0.757950  0.785317       NaN
# 7  0.376643  0.457128  0.674428       NaN
# 8  0.345168  0.011876  0.376801       NaN
# 9  0.328174  0.480911  0.704440       NaN

# %%
#リストワイズ削除(NaNがある行をすべて取り除く)
df.dropna()
# Out:
#           0         1         2         3
# 0  0.602468  0.768027  0.766677  0.449735
# 3  0.811484  0.744376  0.333719  0.533052
# 4  0.817702  0.421772  0.268190  0.029585

# %%
#ペアワイズ削除(欠損している列のデータを無視)
#使いたい列を取り出してからdropnaメソッド

df[[0,1]].dropna()
# Out:
#           0         1
# 0  0.602468  0.768027
# 2  0.666241  0.240078
# 3  0.811484  0.744376
# 4  0.817702  0.421772
# 5  0.663275  0.565867
# 6  0.678600  0.757950
# 7  0.376643  0.457128
# 8  0.345168  0.011876
# 9  0.328174  0.480911

# %%
#fillnaで埋める

df.fillna(0)
# Out:
#           0         1         2         3
# 0  0.602468  0.768027  0.766677  0.449735
# 1  0.000000  0.923134  0.971350  0.540832
# 2  0.666241  0.240078  0.000000  0.326597
# 3  0.811484  0.744376  0.333719  0.533052
# 4  0.817702  0.421772  0.268190  0.029585
# 5  0.663275  0.565867  0.247369  0.000000
# 6  0.678600  0.757950  0.785317  0.000000
# 7  0.376643  0.457128  0.674428  0.000000
# 8  0.345168  0.011876  0.376801  0.000000
# 9  0.328174  0.480911  0.704440  0.000000

# %%
#ffillメソッドは直前の行の値で埋められる

df.fillna(method = 'ffill')
# Out:
# /tmp/ipython-input-1900856658.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'ffill')
#           0         1         2         3
# 0  0.602468  0.768027  0.766677  0.449735
# 1  0.602468  0.923134  0.971350  0.540832
# 2  0.666241  0.240078  0.971350  0.326597
# 3  0.811484  0.744376  0.333719  0.533052
# 4  0.817702  0.421772  0.268190  0.029585
# 5  0.663275  0.565867  0.247369  0.029585
# 6  0.678600  0.757950  0.785317  0.029585
# 7  0.376643  0.457128  0.674428  0.029585
# 8  0.345168  0.011876  0.376801  0.029585
# 9  0.328174  0.480911  0.704440  0.029585

# %%
#平均値代入法
df.mean()
# Out:
# 0    0.587751
# 1    0.537112
# 2    0.569810
# 3    0.375960
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#           0         1         2         3
# 0  0.602468  0.768027  0.766677  0.449735
# 1  0.587751  0.923134  0.971350  0.540832
# 2  0.666241  0.240078  0.569810  0.326597
# 3  0.811484  0.744376  0.333719  0.533052
# 4  0.817702  0.421772  0.268190  0.029585
# 5  0.663275  0.565867  0.247369  0.375960
# 6  0.678600  0.757950  0.785317  0.375960
# 7  0.376643  0.457128  0.674428  0.375960
# 8  0.345168  0.011876  0.376801  0.375960
# 9  0.328174  0.480911  0.704440  0.375960

# %%
df2 = pd.DataFrame(np.random.rand(15,6))

df2.iloc[2,0] = NA
df2.iloc[5:9,2] = NA
df2.iloc[7:10,3] = NA
df2.iloc[10,5] = NA

df2
# Out:
#            0         1         2         3         4         5
# 0   0.095449  0.066567  0.304830  0.924092  0.982232  0.874502
# 1   0.480165  0.195182  0.226402  0.039210  0.693558  0.405131
# 2        NaN  0.423341  0.545062  0.405691  0.323464  0.762119
# 3   0.398419  0.297473  0.043215  0.762210  0.347135  0.545973
# 4   0.115113  0.106288  0.628392  0.862823  0.526243  0.365647
# 5   0.306289  0.105476       NaN  0.915680  0.975225  0.274727
# 6   0.896838  0.551849       NaN  0.967974  0.747719  0.124396
# 7   0.014359  0.682207       NaN       NaN  0.050351  0.327746
# 8   0.287001  0.323968       NaN       NaN  0.280647  0.108763
# 9   0.155806  0.477729  0.709504       NaN  0.913699  0.748253
# 10  0.957128  0.295471  0.321536  0.754622  0.391929       NaN
# 11  0.362863  0.871156  0.704514  0.792171  0.418425  0.745169
# 12  0.410282  0.638812  0.587054  0.031059  0.507175  0.393576
# 13  0.176567  0.870970  0.306999  0.019793  0.034000  0.477417
# ...

# %%
df2.dropna()
# Out:
#            0         1         2         3         4         5
# 0   0.095449  0.066567  0.304830  0.924092  0.982232  0.874502
# 1   0.480165  0.195182  0.226402  0.039210  0.693558  0.405131
# 3   0.398419  0.297473  0.043215  0.762210  0.347135  0.545973
# 4   0.115113  0.106288  0.628392  0.862823  0.526243  0.365647
# 11  0.362863  0.871156  0.704514  0.792171  0.418425  0.745169
# 12  0.410282  0.638812  0.587054  0.031059  0.507175  0.393576
# 13  0.176567  0.870970  0.306999  0.019793  0.034000  0.477417
# 14  0.499626  0.484493  0.789903  0.722334  0.442321  0.336866

# %%
df2.fillna(0)
# Out:
#            0         1         2         3         4         5
# 0   0.095449  0.066567  0.304830  0.924092  0.982232  0.874502
# 1   0.480165  0.195182  0.226402  0.039210  0.693558  0.405131
# 2   0.000000  0.423341  0.545062  0.405691  0.323464  0.762119
# 3   0.398419  0.297473  0.043215  0.762210  0.347135  0.545973
# 4   0.115113  0.106288  0.628392  0.862823  0.526243  0.365647
# 5   0.306289  0.105476  0.000000  0.915680  0.975225  0.274727
# 6   0.896838  0.551849  0.000000  0.967974  0.747719  0.124396
# 7   0.014359  0.682207  0.000000  0.000000  0.050351  0.327746
# 8   0.287001  0.323968  0.000000  0.000000  0.280647  0.108763
# 9   0.155806  0.477729  0.709504  0.000000  0.913699  0.748253
# 10  0.957128  0.295471  0.321536  0.754622  0.391929  0.000000
# 11  0.362863  0.871156  0.704514  0.792171  0.418425  0.745169
# 12  0.410282  0.638812  0.587054  0.031059  0.507175  0.393576
# 13  0.176567  0.870970  0.306999  0.019793  0.034000  0.477417
# ...

# %%
df2.fillna(df2.mean())
# Out:
#            0         1         2         3         4         5
# 0   0.095449  0.066567  0.304830  0.924092  0.982232  0.874502
# 1   0.480165  0.195182  0.226402  0.039210  0.693558  0.405131
# 2   0.368279  0.423341  0.545062  0.405691  0.323464  0.762119
# 3   0.398419  0.297473  0.043215  0.762210  0.347135  0.545973
# 4   0.115113  0.106288  0.628392  0.862823  0.526243  0.365647
# 5   0.306289  0.105476  0.469765  0.915680  0.975225  0.274727
# 6   0.896838  0.551849  0.469765  0.967974  0.747719  0.124396
# 7   0.014359  0.682207  0.469765  0.599805  0.050351  0.327746
# 8   0.287001  0.323968  0.469765  0.599805  0.280647  0.108763
# 9   0.155806  0.477729  0.709504  0.599805  0.913699  0.748253
# 10  0.957128  0.295471  0.321536  0.754622  0.391929  0.463592
# 11  0.362863  0.871156  0.704514  0.792171  0.418425  0.745169
# 12  0.410282  0.638812  0.587054  0.031059  0.507175  0.393576
# 13  0.176567  0.870970  0.306999  0.019793  0.034000  0.477417
# ...

# %%
# !pip install pandas-datareader

# %%
import pandas_datareader.data as pdr

# %%
#時系列データ
start_date = '2001/1/2'
end_date ='2016/12/30'

fx_jpusdata = pdr.DataReader('DEXJPUS','fred',start_date, end_date)

# %%
fx_jpusdata
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-08   115.97
# ...             ...
# 2016-12-26      NaN
# 2016-12-27   117.52
# 2016-12-28   117.66
# 2016-12-29   116.32
# 2016-12-30   116.78
#
# [4174 rows x 1 columns]

# %%
#特定の年月を参照
fx_jpusdata.loc['2016-04']
# Out:
#             DEXJPUS
# DATE
# 2016-04-01   112.06
# 2016-04-04   111.18
# 2016-04-05   110.26
# 2016-04-06   109.63
# 2016-04-07   107.98
# 2016-04-08   108.36
# 2016-04-11   107.96
# 2016-04-12   108.54
# 2016-04-13   109.21
# 2016-04-14   109.20
# 2016-04-15   108.76
# 2016-04-18   108.85
# 2016-04-19   109.16
# 2016-04-20   109.51
# 2016-04-21   109.41
# 2016-04-22   111.50
# 2016-04-25   111.08
# 2016-04-26   111.23
# 2016-04-27   111.26
# 2016-04-28   108.55
# 2016-04-29   106.90

# %%
#'MS' → 月初 (MonthStart)
#'ME' → 月末 (MonthEnd) ← 今後はこちらを推奨
fx_jpusdata.resample('ME').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-31   116.39
# 2001-02-28   117.28
# 2001-03-31   125.54
# 2001-04-30   123.57
# 2001-05-31   118.88

# %%
#日付を取り出したい時は'D',年を取り出したい時は'Y'
fx_jpusdata.resample('D').last().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-06      NaN

# %%
#欠損を前日で埋める
fx_jpusdata.resample('D').ffill().head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-06   116.19

# %%
#データをずらして比率を計算する
#shiftメソッドを使うことでindexは固定したままデータだけをずらせる

fx_jpusdata.shift(1).head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02      NaN
# 2001-01-03   114.73
# 2001-01-04   114.26
# 2001-01-05   115.47
# 2001-01-08   116.19

# %%
#前日と当日のレートの比を算出
fx_jpusdata_ratio = fx_jpusdata / fx_jpusdata.shift(1)
fx_jpusdata_ratio.head()
# Out:
#              DEXJPUS
# DATE
# 2001-01-02       NaN
# 2001-01-03  0.995903
# 2001-01-04  1.010590
# 2001-01-05  1.006235
# 2001-01-08  0.998107

# %%
fx_jpusdata.resample('Y').mean()
# Out:
# /tmp/ipython-input-2186083808.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   fx_jpusdata.resample('Y').mean()
#                DEXJPUS
# DATE
# 2001-12-31  121.568040
# 2002-12-31  125.220438
# 2003-12-31  115.938685
# 2004-12-31  108.150830
# 2005-12-31  110.106932
# 2006-12-31  116.312072
# 2007-12-31  117.762323
# 2008-12-31  103.390635
# 2009-12-31   93.682659
# 2010-12-31   87.781680
# 2011-12-31   79.696653
# 2012-12-31   79.818008
# 2013-12-31   97.597131
# 2014-12-31  105.739800
# 2015-12-31  121.049084
# 2016-12-31  108.656932

# %%
#移動平均
fx_jpusdata.head()
# Out:
#             DEXJPUS
# DATE
# 2001-01-02   114.73
# 2001-01-03   114.26
# 2001-01-04   115.47
# 2001-01-05   116.19
# 2001-01-08   115.97

# %%
#rollingメソッドを実行後，meanメソッド
fx_jpusdata.rolling(3).mean()
# Out:
#                DEXJPUS
# DATE
# 2001-01-02         NaN
# 2001-01-03         NaN
# 2001-01-04  114.820000
# 2001-01-05  115.306667
# 2001-01-08  115.876667
# ...                ...
# 2016-12-26         NaN
# 2016-12-27         NaN
# 2016-12-28         NaN
# 2016-12-29  117.166667
# 2016-12-30  116.920000
#
# [4174 rows x 1 columns]

# %%
#標準偏差の推移はstdメソッド
fx_jpusdata.rolling(3).std().head()
# Out:
#              DEXJPUS
# DATE
# 2001-01-02       NaN
# 2001-01-03       NaN
# 2001-01-04  0.610000
# 2001-01-05  0.975312
# 2001-01-08  0.368963

# %%
fx = fx_jpusdata.rolling(20).mean()
fx.dropna()
# Out:
#              DEXJPUS
# DATE
# 2001-02-12  116.6910
# 2001-02-13  116.6920
# 2001-02-14  116.6070
# 2001-02-15  116.5015
# 2001-02-16  116.4130
# ...              ...
# 2016-11-08  104.1600
# 2016-11-09  104.1780
# 2016-11-10  104.3250
# 2016-12-22  115.1555
# 2016-12-23  115.3580
#
# [1593 rows x 1 columns]

# %%
# Out:
#           0         1         2         3
# 0  0.602468  0.768027  0.766677  0.449735
# 1       NaN  0.923134  0.971350  0.540832
# 2  0.666241  0.240078       NaN  0.326597
# 3  0.811484  0.744376  0.333719  0.533052
# 4  0.817702  0.421772  0.268190  0.029585
# 5  0.663275  0.565867  0.247369       NaN
# 6  0.678600  0.757950  0.785317       NaN
# 7  0.376643  0.457128  0.674428       NaN
# 8  0.345168  0.011876  0.376801       NaN
# 9  0.328174  0.480911  0.704440       NaN

# %%
df = pd.read_csv('/content/student-mat.csv',sep = ';')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df1 = df.groupby(['age','sex'])['G1'].mean()
df1
# Out:
# age  sex
# 15   F      10.052632
#      M      12.250000
# 16   F      10.203704
#      M      11.740000
# 17   F      11.103448
#      M      10.600000
# 18   F      10.883721
#      M      10.538462
# 19   F      10.642857
#      M       9.700000
# 20   F      15.000000
#      M      13.000000
# 21   M      10.000000
# 22   M       6.000000
# Name: G1, dtype: float64

# %%
df1 = df1.unstack()
df1
# Out:
# sex          F          M
# age
# 15   10.052632  12.250000
# 16   10.203704  11.740000
# 17   11.103448  10.600000
# 18   10.883721  10.538462
# 19   10.642857   9.700000
# 20   15.000000  13.000000
# 21         NaN  10.000000
# 22         NaN   6.000000

# %%
df1.dropna()
# Out:
# sex          F          M
# age
# 15   10.052632  12.250000
# 16   10.203704  11.740000
# 17   11.103448  10.600000
# 18   10.883721  10.538462
# 19   10.642857   9.700000
# 20   15.000000  13.000000
