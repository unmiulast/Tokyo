# %% [markdown]
# <a href="https://colab.research.google.com/github/unmiulast/Tokyo/blob/main/3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()

# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
from sklearn import linear_model

# %%
df = pd.read_csv('student-mat.csv',sep = ';')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.groupby('sex')['age'].mean()
# Out:
# sex
# F    16.730769
# M    16.657754
# Name: age, dtype: float64

# %%
df.groupby('sex')['G3'].mean()
# Out:
# sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %%
plt.hist(df['absences'],bins = 15)

plt.xlabel('absences')
plt.ylabel('count')

plt.grid(True)

plt.show()

# %% [markdown]
# ロングテール（分布の裾が緩やかに減少している）分布
#
# 右に歪みのある分布

# %%
df['absences'].describe()
# Out:
# count    395.000000
# mean       5.708861
# std        8.003096
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max       75.000000
# Name: absences, dtype: float64

# %% [markdown]
# 標準偏差はn-1 で割る不偏分散の平方根で算出

# %%
df['absences'].var(ddof = 0)
# Out:
# 63.887

# %%
df['absences'].std(ddof = 0)
# Out:
# 7.993

# %% [markdown]
# nで割る

# %%
#四分位範囲を求める
print(df['absences'].describe()['75%'] - df['absences'].describe()['25%'])
# Out:
# 8.0

# %% [markdown]
# describe() の戻り値は Series で、インデックスに統計量のラベル（例：'mean', 'std', 'min', '25%', '50%', '75%', 'max'）がついています。

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
plt.boxplot(df['absences'])
plt.grid(True)

plt.show()

# %%
plt.boxplot([df['G1'],df['G2'],df['G3']])
plt.grid(True)

plt.show()

# %%
#変動係数　スケールに依存せず，比較が可能に
df['absences'].std(ddof = 0) / df['absences'].mean()
# Out:
# np.float64(1.4000969901232916)

# %%
numeric_df = df.select_dtypes(include='number')

numeric_df.std(ddof = 0) / numeric_df.mean()
# Out:
# age           0.076330
# Medu          0.397673
# Fedu          0.431019
# traveltime    0.481058
# studytime     0.411791
# failures      2.222501
# famrel        0.227042
# freetime      0.308334
# goout         0.357645
# Dalc          0.600679
# Walc          0.561409
# health        0.390651
# absences      1.400097
# G1            0.303881
# G2            0.350641
# G3            0.439324
# dtype: float64

# %%
plt.plot(df['G1'],df['G3'],'o')

plt.xlabel('G1')
plt.ylabel('G3')

plt.grid(True)
plt.show()

# %%
np.cov(df['G1'], df['G3'], ddof = 0)
# Out:
# array([[10.989, 12.157],
#        [12.157, 20.936]])

# %% [markdown]
# 共分散 12.157 2組の偏差の積の平均値
#
# G1の分散　10.989
#
# G3の分散　20.936

# %%
sp.stats.pearsonr(df['G1'], df['G3'])
# Out:
# PearsonRResult(statistic=np.float64(0.8014679320174143), pvalue=np.float64(9.001430312274863e-90))

# %% [markdown]
# 共分散は変数のスケールや単位に依存
#
# 相関係数は共分散をそれぞれの変数の標準偏差で割る

# %% [markdown]
# 相関係数　0.8014679320174143
#
# p値　9.001430312274863e-90

# %%
#相関行列
np.corrcoef(df['G1'], df['G3'])
# Out:
# array([[1.   , 0.801],
#        [0.801, 1.   ]])

# %%
sns.pairplot(df[['G1', 'G3', 'Dalc', 'Walc']])
plt.grid(True)

plt.show()

# %%
numeric_df = df.select_dtypes(include='number')
sns.pairplot(numeric_df)
plt.grid(True)

plt.show()

# %%
df_2 = pd.read_csv('/content/student-por.csv',sep = ';')
df_2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df_2.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
df_merge = pd.merge(df,df_2,on = ['school', 'sex', 'age', 'address','famsize','Pstatus','Medu','Fedu','Mjob','Fjob','reason','nursery','internet'],
                    suffixes = ('_math', '_por'))
df_merge
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 377     MS   F   18       U     LE3       T     3     1   teacher  services
# 378     MS   F   18       U     GT3       T     1     1     other     other
# 379     MS   F   18       U     GT3       T     1     1     other     other
# 380     MS   M   17       U     LE3       T     3     1  services  services
# 381     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df_merge.describe()
# Out:
#               age        Medu        Fedu  traveltime_math  studytime_math  \
# count  382.000000  382.000000  382.000000       382.000000      382.000000
# mean    16.586387    2.806283    2.565445         1.442408        2.034031
# std      1.173470    1.086381    1.096240         0.695378        0.845798
# min     15.000000    0.000000    0.000000         1.000000        1.000000
# 25%     16.000000    2.000000    2.000000         1.000000        1.000000
# 50%     17.000000    3.000000    3.000000         1.000000        2.000000
# 75%     17.000000    4.000000    4.000000         2.000000        2.000000
# max     22.000000    4.000000    4.000000         4.000000        4.000000
#
#        failures_math  famrel_math  freetime_math  goout_math   Dalc_math  ...  \
# count     382.000000   382.000000     382.000000  382.000000  382.000000  ...
# mean        0.290576     3.939791       3.222513    3.112565    1.473822  ...
# ...

# %%
sns.pairplot(df_merge[['Medu','Fedu','G3_math']])
plt.grid(True)

plt.show()

# %%
#線形回帰のインスタンスを作成
reg = linear_model.LinearRegression()

# %%
#df.loc[:, 'G1'] → 行は全て，列名 'G1' を指定
X = df.loc[:,['G1']].values

Y =df['G3'].values

reg.fit(X,Y)

print('回帰係数', reg.coef_)
print('切片', reg.intercept_)
# Out:
# 回帰係数 [1.106]
# 切片 -1.6528038288004634

# %% [markdown]
# 説明変数XがG1,目的変数YがG3

# %% [markdown]
# fit関数は最小二乗法で回帰係数aと切片bを計算する
#
# 実際のデータと予測データの2乗和をとってそれが最小になるような
# 回帰係数と切片を求める
#
# y = ax + b

# %%
plt.scatter(X, Y)
plt.xlabel('G1')
plt.ylabel('G3')

plt.plot(X, reg.predict(X))

plt.grid(True)

# %%
reg.score(X, Y)
# Out:
# 0.642

# %% [markdown]
# 決定係数（寄与率）は予測式の精度を客観的に数値化したもの
# 最大値1で大きいほど良いモデル
# 説明変数を使わず平均値で予測したものとの二乗差が等しいと0になる

# %%
reg2 = linear_model.LinearRegression()

# %%
X2 = df_2.loc[:,['G1']].values

Y2 = df_2['G3'].values

reg2.fit(X2, Y2)
print(reg2.coef_, reg2.intercept_, reg2.score(X2,Y2))
# Out:
# [0.973] 0.8203984121064583 0.6829156800171083

# %%
plt.scatter(X2, Y2)
plt.xlabel('G1')
plt.ylabel('G3')
plt.grid(True)

plt.plot(X2, reg2.predict(X2))

# %%
reg = linear_model.LinearRegression()

X = df_2.loc[:,['absences']].values

Y = df_2['G3'].values

reg.fit(X,Y)

print(reg.coef_, reg.intercept_, reg.score(X,Y))
# Out:
# [-0.064] 12.138800862687443 0.008350131955637385

# %%
plt.scatter(X, Y)
plt.xlabel('G1')
plt.ylabel('G3')

plt.plot(X, reg.predict(X))

plt.grid(True)

# %%
df = pd.read_csv('/content/winequality-red.csv',sep = ';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
sns.pairplot(df)
